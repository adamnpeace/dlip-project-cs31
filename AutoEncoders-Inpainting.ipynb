# %% [markdown]
# # Image Denoiser using 2-layer

# %%
import os
import skimage
import numpy as np
import pandas as pd
import tensorflow as tf
from sklearn.model_selection import train_test_split
from matplotlib import pyplot as plt

from keras.layers import Input, Dense, Conv2D, MaxPooling2D, UpSampling2D
from keras.models import Model, load_model
from keras.callbacks import ModelCheckpoint
from keras import backend as K
# Out:
# Using TensorFlow backend.

# %%
model_file = "proper_ae_inpaint_model.h5"

folder_path = "data/inpainted_1_5_pairs"
num_samples = 2000
image_dims = (128, 128)

# %%
def pretty_print(data, n=10):
    plt.figure(figsize=(2 * n, 2))
    for i in range(1, n+1):
        ax = plt.subplot(1, n, i)
        plt.imshow(data[i].reshape(image_dims))
        plt.gray()
        ax.get_xaxis().set_visible(False)
        ax.get_yaxis().set_visible(False)
    plt.show()

# %%
x = np.ndarray((num_samples, image_dims[0], image_dims[1]))
y = np.ndarray((num_samples, image_dims[0], image_dims[1]))
for i in range(num_samples):
    x[i] = skimage.io.imread("{}/f_fbp/{}.tif".format(folder_path, i))
    y[i] = skimage.io.imread("{}/f_true/{}.tif".format(folder_path, i))
    
# Normalize values
x = x.astype('float32') / 255.
y = y.astype('float32') / 255.

# Desired shape for keras is (n_samples, x, y, n_channels)
x = np.reshape(x, (len(x), image_dims[0], image_dims[1], 1))
y = np.reshape(y, (len(y), image_dims[0], image_dims[1], 1))

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.1, random_state=42)

# %%
y_train.shape
# Out:
# (1800, 128, 128, 1)

# %%
y_test.shape
# Out:
# (200, 128, 128, 1)

# %%
pretty_print(x_test)

# %%
pretty_print(y_test)

# %%
input_img = Input(shape=(128, 128, 1)) # x, y, n_channels

# Model Architecture
x = Conv2D(32, (3, 3), activation='relu', padding='same')(input_img)
x = MaxPooling2D((2, 2), padding='same')(x)
x = Conv2D(32, (3, 3), activation='relu', padding='same')(x)
encoded = MaxPooling2D((2, 2), padding='same')(x)

# at this point the representation is (7, 7, 32)

x = Conv2D(32, (3, 3), activation='relu', padding='same')(encoded)
x = UpSampling2D((2, 2))(x)
x = Conv2D(32, (3, 3), activation='relu', padding='same')(x)
x = UpSampling2D((2, 2))(x)
decoded = Conv2D(1, (3, 3), activation='sigmoid', padding='same')(x)

autoencoder = Model(input_img, decoded)
autoencoder.compile(optimizer='adadelta', loss='binary_crossentropy')
# Out:
# WARNING:tensorflow:From /Users/ap/.pyenv/versions/anaconda3-5.2.0/lib/python3.6/site-packages/tensorflow/python/ops/resource_variable_ops.py:435: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.

# %%
# Define the model checkpoint
filepath = model_file
checkpoint = ModelCheckpoint(filepath, monitor='loss', verbose=1, save_best_only=True, mode='min')
callbacks_list = [checkpoint]

# %%
autoencoder.fit(x_train, y_train,
                epochs=100,
                batch_size=128,
                shuffle=True,
#                 validation_data=(x_test, y_test),
                callbacks=callbacks_list
               )
# Out:
# WARNING:tensorflow:From /Users/ap/.pyenv/versions/anaconda3-5.2.0/lib/python3.6/site-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Epoch 1/100
# 1800/1800 [==============================] - 92s 51ms/step - loss: 0.5919
#
# Epoch 00001: loss improved from inf to 0.59186, saving model to proper_ae_inpaint_model.h5
# Epoch 2/100
# 1800/1800 [==============================] - 83s 46ms/step - loss: 0.5365
#
# Epoch 00002: loss improved from 0.59186 to 0.53650, saving model to proper_ae_inpaint_model.h5
# Epoch 3/100
# 1800/1800 [==============================] - 82s 46ms/step - loss: 0.5185
#
# Epoch 00003: loss improved from 0.53650 to 0.51848, saving model to proper_ae_inpaint_model.h5
# Epoch 4/100
# 1800/1800 [==============================] - 81s 45ms/step - loss: 0.4601
#
# Epoch 00004: loss improved from 0.51848 to 0.46007, saving model to proper_ae_inpaint_model.h5
# Epoch 5/100
# 1800/1800 [==============================] - 82s 45ms/step - loss: 0.4199
#
# Epoch 00005: loss improved from 0.46007 to 0.41987, saving model to proper_ae_inpaint_model.h5
# Epoch 6/100
# 1800/1800 [==============================] - 81s 45ms/step - loss: 0.3641
#
# Epoch 00006: loss improved from 0.41987 to 0.36406, saving model to proper_ae_inpaint_model.h5
# Epoch 7/100
# 1800/1800 [==============================] - 81s 45ms/step - loss: 0.3474
#
# Epoch 00007: loss improved from 0.36406 to 0.34744, saving model to proper_ae_inpaint_model.h5
# Epoch 8/100
# 1800/1800 [==============================] - 81s 45ms/step - loss: 0.3287
#
# Epoch 00008: loss improved from 0.34744 to 0.32870, saving model to proper_ae_inpaint_model.h5
# Epoch 9/100
# 1800/1800 [==============================] - 81s 45ms/step - loss: 0.3256
#
# Epoch 00009: loss improved from 0.32870 to 0.32557, saving model to proper_ae_inpaint_model.h5
# Epoch 10/100
# 1800/1800 [==============================] - 81s 45ms/step - loss: 0.3117
#
# Epoch 00010: loss improved from 0.32557 to 0.31169, saving model to proper_ae_inpaint_model.h5
# Epoch 11/100
# 1800/1800 [==============================] - 81s 45ms/step - loss: 0.3154
#
# Epoch 00011: loss did not improve from 0.31169
# Epoch 12/100
# 1800/1800 [==============================] - 81s 45ms/step - loss: 0.2958
#
# Epoch 00012: loss improved from 0.31169 to 0.29576, saving model to proper_ae_inpaint_model.h5
# Epoch 13/100
# 1800/1800 [==============================] - 81s 45ms/step - loss: 0.2914
#
# Epoch 00013: loss improved from 0.29576 to 0.29143, saving model to proper_ae_inpaint_model.h5
# Epoch 14/100
# 1800/1800 [==============================] - 81s 45ms/step - loss: 0.2893
#
# Epoch 00014: loss improved from 0.29143 to 0.28925, saving model to proper_ae_inpaint_model.h5
# Epoch 15/100
# 1800/1800 [==============================] - 81s 45ms/step - loss: 0.2834
#
# Epoch 00015: loss improved from 0.28925 to 0.28341, saving model to proper_ae_inpaint_model.h5
# Epoch 16/100
# 1800/1800 [==============================] - 81s 45ms/step - loss: 0.2841
#
# Epoch 00016: loss did not improve from 0.28341
# Epoch 17/100
# 1800/1800 [==============================] - 81s 45ms/step - loss: 0.2733
#
# Epoch 00017: loss improved from 0.28341 to 0.27334, saving model to proper_ae_inpaint_model.h5
# Epoch 18/100
# 1800/1800 [==============================] - 81s 45ms/step - loss: 0.2524
#
# Epoch 00018: loss improved from 0.27334 to 0.25239, saving model to proper_ae_inpaint_model.h5
# Epoch 19/100
# 1800/1800 [==============================] - 81s 45ms/step - loss: 0.2543
#
# Epoch 00019: loss did not improve from 0.25239
# Epoch 20/100
# 1800/1800 [==============================] - 81s 45ms/step - loss: 0.2464
#
# Epoch 00020: loss improved from 0.25239 to 0.24643, saving model to proper_ae_inpaint_model.h5
# Epoch 21/100
# 1800/1800 [==============================] - 81s 45ms/step - loss: 0.2383
#
# Epoch 00021: loss improved from 0.24643 to 0.23829, saving model to proper_ae_inpaint_model.h5
# Epoch 22/100
# 1800/1800 [==============================] - 81s 45ms/step - loss: 0.2312
#
# Epoch 00022: loss improved from 0.23829 to 0.23116, saving model to proper_ae_inpaint_model.h5
# Epoch 23/100
# 1800/1800 [==============================] - 81s 45ms/step - loss: 0.2268
#
# Epoch 00023: loss improved from 0.23116 to 0.22679, saving model to proper_ae_inpaint_model.h5
# Epoch 24/100
# 1800/1800 [==============================] - 81s 45ms/step - loss: 0.2157
#
# Epoch 00024: loss improved from 0.22679 to 0.21568, saving model to proper_ae_inpaint_model.h5
# Epoch 25/100
# 1800/1800 [==============================] - 81s 45ms/step - loss: 0.2247
#
# Epoch 00025: loss did not improve from 0.21568
# Epoch 26/100
# 1800/1800 [==============================] - 81s 45ms/step - loss: 0.2197
#
# Epoch 00026: loss did not improve from 0.21568
# Epoch 27/100
# 1800/1800 [==============================] - 81s 45ms/step - loss: 0.2023
#
# Epoch 00027: loss improved from 0.21568 to 0.20232, saving model to proper_ae_inpaint_model.h5
# Epoch 28/100
# 1800/1800 [==============================] - 82s 45ms/step - loss: 0.1961
#
# Epoch 00028: loss improved from 0.20232 to 0.19614, saving model to proper_ae_inpaint_model.h5
# Epoch 29/100
# 1800/1800 [==============================] - 81s 45ms/step - loss: 0.1963
#
# Epoch 00029: loss did not improve from 0.19614
# Epoch 30/100
# 1800/1800 [==============================] - 81s 45ms/step - loss: 0.1900
#
# Epoch 00030: loss improved from 0.19614 to 0.19005, saving model to proper_ae_inpaint_model.h5
# Epoch 31/100
# 1800/1800 [==============================] - 81s 45ms/step - loss: 0.1751
#
# Epoch 00031: loss improved from 0.19005 to 0.17509, saving model to proper_ae_inpaint_model.h5
# Epoch 32/100
# 1800/1800 [==============================] - 81s 45ms/step - loss: 0.1842
#
# Epoch 00032: loss did not improve from 0.17509
# Epoch 33/100
# 1800/1800 [==============================] - 81s 45ms/step - loss: 0.1642
#
# Epoch 00033: loss improved from 0.17509 to 0.16423, saving model to proper_ae_inpaint_model.h5
# Epoch 34/100
# 1800/1800 [==============================] - 81s 45ms/step - loss: 0.1678
#
# Epoch 00034: loss did not improve from 0.16423
# Epoch 35/100
# 1800/1800 [==============================] - 82s 45ms/step - loss: 0.1598
#
# Epoch 00035: loss improved from 0.16423 to 0.15980, saving model to proper_ae_inpaint_model.h5
# Epoch 36/100
# 1800/1800 [==============================] - 81s 45ms/step - loss: 0.1565
#
# Epoch 00036: loss improved from 0.15980 to 0.15652, saving model to proper_ae_inpaint_model.h5
# Epoch 37/100
# 1800/1800 [==============================] - 81s 45ms/step - loss: 0.1444
#
# Epoch 00037: loss improved from 0.15652 to 0.14437, saving model to proper_ae_inpaint_model.h5
# Epoch 38/100
# 1800/1800 [==============================] - 81s 45ms/step - loss: 0.1553
#
# Epoch 00038: loss did not improve from 0.14437
# Epoch 39/100
# 1800/1800 [==============================] - 81s 45ms/step - loss: 0.1487
#
# Epoch 00039: loss did not improve from 0.14437
# Epoch 40/100
# 1800/1800 [==============================] - 81s 45ms/step - loss: 0.1376
#
# Epoch 00040: loss improved from 0.14437 to 0.13763, saving model to proper_ae_inpaint_model.h5
# Epoch 41/100
# 1800/1800 [==============================] - 81s 45ms/step - loss: 0.1361
#
# Epoch 00041: loss improved from 0.13763 to 0.13606, saving model to proper_ae_inpaint_model.h5
# Epoch 42/100
# 1800/1800 [==============================] - 79s 44ms/step - loss: 0.1336
#
# Epoch 00042: loss improved from 0.13606 to 0.13365, saving model to proper_ae_inpaint_model.h5
# Epoch 43/100
# 1800/1800 [==============================] - 78s 43ms/step - loss: 0.1393
#
# Epoch 00043: loss did not improve from 0.13365
# Epoch 44/100
# 1800/1800 [==============================] - 78s 43ms/step - loss: 0.1306
#
# Epoch 00044: loss improved from 0.13365 to 0.13056, saving model to proper_ae_inpaint_model.h5
# Epoch 45/100
# 1800/1800 [==============================] - 78s 43ms/step - loss: 0.1259
#
# Epoch 00045: loss improved from 0.13056 to 0.12586, saving model to proper_ae_inpaint_model.h5
# Epoch 46/100
# 1800/1800 [==============================] - 78s 44ms/step - loss: 0.1296
#
# Epoch 00046: loss did not improve from 0.12586
# Epoch 47/100
# 1800/1800 [==============================] - 78s 44ms/step - loss: 0.1237
#
# Epoch 00047: loss improved from 0.12586 to 0.12374, saving model to proper_ae_inpaint_model.h5
# Epoch 48/100
# 1800/1800 [==============================] - 78s 43ms/step - loss: 0.1184
#
# Epoch 00048: loss improved from 0.12374 to 0.11836, saving model to proper_ae_inpaint_model.h5
# Epoch 49/100
# 1800/1800 [==============================] - 78s 44ms/step - loss: 0.1184
#
# Epoch 00049: loss improved from 0.11836 to 0.11836, saving model to proper_ae_inpaint_model.h5
# Epoch 50/100
# 1800/1800 [==============================] - 78s 43ms/step - loss: 0.1177
#
# Epoch 00050: loss improved from 0.11836 to 0.11770, saving model to proper_ae_inpaint_model.h5
# Epoch 51/100
# 1800/1800 [==============================] - 78s 44ms/step - loss: 0.1199
#
# Epoch 00051: loss did not improve from 0.11770
# Epoch 52/100
# 1800/1800 [==============================] - 78s 43ms/step - loss: 0.1135
#
# Epoch 00052: loss improved from 0.11770 to 0.11348, saving model to proper_ae_inpaint_model.h5
# Epoch 53/100
# 1800/1800 [==============================] - 78s 43ms/step - loss: 0.1093
#
# Epoch 00053: loss improved from 0.11348 to 0.10935, saving model to proper_ae_inpaint_model.h5
# Epoch 54/100
# 1800/1800 [==============================] - 79s 44ms/step - loss: 0.1174
#
# Epoch 00054: loss did not improve from 0.10935
# Epoch 55/100
# 1800/1800 [==============================] - 81s 45ms/step - loss: 0.1154
#
# Epoch 00055: loss did not improve from 0.10935
# Epoch 56/100
# 1800/1800 [==============================] - 81s 45ms/step - loss: 0.1110
#
# Epoch 00056: loss did not improve from 0.10935
# Epoch 57/100
# 1800/1800 [==============================] - 81s 45ms/step - loss: 0.1172
#
# Epoch 00057: loss did not improve from 0.10935
# Epoch 58/100
# 1800/1800 [==============================] - 81s 45ms/step - loss: 0.1103
#
# Epoch 00058: loss did not improve from 0.10935
# Epoch 59/100
# 1800/1800 [==============================] - 81s 45ms/step - loss: 0.1086
#
# Epoch 00059: loss improved from 0.10935 to 0.10865, saving model to proper_ae_inpaint_model.h5
# Epoch 60/100
# 1800/1800 [==============================] - 81s 45ms/step - loss: 0.1220
#
# Epoch 00060: loss did not improve from 0.10865
# Epoch 61/100
# 1800/1800 [==============================] - 81s 45ms/step - loss: 0.1044
#
# Epoch 00061: loss improved from 0.10865 to 0.10438, saving model to proper_ae_inpaint_model.h5
# Epoch 62/100
# 1800/1800 [==============================] - 81s 45ms/step - loss: 0.1066
#
# Epoch 00062: loss did not improve from 0.10438
# Epoch 63/100
# 1800/1800 [==============================] - 81s 45ms/step - loss: 0.1080
#
# Epoch 00063: loss did not improve from 0.10438
# Epoch 64/100
# 1800/1800 [==============================] - 81s 45ms/step - loss: 0.1015
#
# Epoch 00064: loss improved from 0.10438 to 0.10153, saving model to proper_ae_inpaint_model.h5
# Epoch 65/100
# 1800/1800 [==============================] - 81s 45ms/step - loss: 0.0998
#
# Epoch 00065: loss improved from 0.10153 to 0.09976, saving model to proper_ae_inpaint_model.h5
# Epoch 66/100
# 1800/1800 [==============================] - 81s 45ms/step - loss: 0.0998
#
# Epoch 00066: loss did not improve from 0.09976
# Epoch 67/100
# 1800/1800 [==============================] - 81s 45ms/step - loss: 0.1009
#
# Epoch 00067: loss did not improve from 0.09976
# Epoch 68/100
# 1800/1800 [==============================] - 81s 45ms/step - loss: 0.1045
#
# Epoch 00068: loss did not improve from 0.09976
# Epoch 69/100
# 1800/1800 [==============================] - 81s 45ms/step - loss: 0.1002
#
# Epoch 00069: loss did not improve from 0.09976
# Epoch 70/100
# 1800/1800 [==============================] - 81s 45ms/step - loss: 0.1019
#
# Epoch 00070: loss did not improve from 0.09976
# Epoch 71/100
# 1800/1800 [==============================] - 81s 45ms/step - loss: 0.0999
#
# Epoch 00071: loss did not improve from 0.09976
# Epoch 72/100
# 1800/1800 [==============================] - 81s 45ms/step - loss: 0.1020
#
# Epoch 00072: loss did not improve from 0.09976
# Epoch 73/100
# 1800/1800 [==============================] - 81s 45ms/step - loss: 0.1051
#
# Epoch 00073: loss did not improve from 0.09976
# Epoch 74/100
# 1800/1800 [==============================] - 81s 45ms/step - loss: 0.0969
#
# Epoch 00074: loss improved from 0.09976 to 0.09693, saving model to proper_ae_inpaint_model.h5
# Epoch 75/100
# 1800/1800 [==============================] - 81s 45ms/step - loss: 0.0962
#
# Epoch 00075: loss improved from 0.09693 to 0.09619, saving model to proper_ae_inpaint_model.h5
# Epoch 76/100
# 1800/1800 [==============================] - 81s 45ms/step - loss: 0.1000
#
# Epoch 00076: loss did not improve from 0.09619
# Epoch 77/100
# 1800/1800 [==============================] - 81s 45ms/step - loss: 0.0964
#
# Epoch 00077: loss did not improve from 0.09619
# Epoch 78/100
# 1800/1800 [==============================] - 81s 45ms/step - loss: 0.0986
#
# Epoch 00078: loss did not improve from 0.09619
# Epoch 79/100
# 1800/1800 [==============================] - 81s 45ms/step - loss: 0.0961
#
# Epoch 00079: loss improved from 0.09619 to 0.09612, saving model to proper_ae_inpaint_model.h5
# Epoch 80/100
# 1800/1800 [==============================] - 81s 45ms/step - loss: 0.0957
#
# Epoch 00080: loss improved from 0.09612 to 0.09571, saving model to proper_ae_inpaint_model.h5
# Epoch 81/100
# 1800/1800 [==============================] - 81s 45ms/step - loss: 0.0957
#
# Epoch 00081: loss did not improve from 0.09571
# Epoch 82/100
# 1800/1800 [==============================] - 81s 45ms/step - loss: 0.0912
#
# Epoch 00082: loss improved from 0.09571 to 0.09121, saving model to proper_ae_inpaint_model.h5
# Epoch 83/100
# 1800/1800 [==============================] - 81s 45ms/step - loss: 0.1009
#
# Epoch 00083: loss did not improve from 0.09121
# Epoch 84/100
# 1800/1800 [==============================] - 81s 45ms/step - loss: 0.0925
#
# Epoch 00084: loss did not improve from 0.09121
# Epoch 85/100
# 1800/1800 [==============================] - 81s 45ms/step - loss: 0.0951
#
# Epoch 00085: loss did not improve from 0.09121
# Epoch 86/100
# 1800/1800 [==============================] - 81s 45ms/step - loss: 0.0941
#
# Epoch 00086: loss did not improve from 0.09121
# Epoch 87/100
# 1800/1800 [==============================] - 81s 45ms/step - loss: 0.0942
#
# Epoch 00087: loss did not improve from 0.09121
# Epoch 88/100
# 1800/1800 [==============================] - 81s 45ms/step - loss: 0.0906
#
# Epoch 00088: loss improved from 0.09121 to 0.09059, saving model to proper_ae_inpaint_model.h5
# Epoch 89/100
# 1800/1800 [==============================] - 81s 45ms/step - loss: 0.0886
#
# Epoch 00089: loss improved from 0.09059 to 0.08858, saving model to proper_ae_inpaint_model.h5
# Epoch 90/100
# 1800/1800 [==============================] - 81s 45ms/step - loss: 0.0903
#
# Epoch 00090: loss did not improve from 0.08858
# Epoch 91/100
# 1800/1800 [==============================] - 81s 45ms/step - loss: 0.0927
#
# Epoch 00091: loss did not improve from 0.08858
# Epoch 92/100
# 1800/1800 [==============================] - 81s 45ms/step - loss: 0.0881
#
# Epoch 00092: loss improved from 0.08858 to 0.08807, saving model to proper_ae_inpaint_model.h5
# Epoch 93/100
# 1800/1800 [==============================] - 81s 45ms/step - loss: 0.0941
#
# Epoch 00093: loss did not improve from 0.08807
# Epoch 94/100
# 1800/1800 [==============================] - 81s 45ms/step - loss: 0.0898
#
# Epoch 00094: loss did not improve from 0.08807
# Epoch 95/100
# 1800/1800 [==============================] - 81s 45ms/step - loss: 0.0894
#
# Epoch 00095: loss did not improve from 0.08807
# Epoch 96/100
# 1800/1800 [==============================] - 81s 45ms/step - loss: 0.0912
#
# Epoch 00096: loss did not improve from 0.08807
# Epoch 97/100
# 1800/1800 [==============================] - 81s 45ms/step - loss: 0.0878
#
# Epoch 00097: loss improved from 0.08807 to 0.08780, saving model to proper_ae_inpaint_model.h5
# Epoch 98/100
# 1800/1800 [==============================] - 81s 45ms/step - loss: 0.0877
#
# Epoch 00098: loss improved from 0.08780 to 0.08775, saving model to proper_ae_inpaint_model.h5
# Epoch 99/100
# 1800/1800 [==============================] - 81s 45ms/step - loss: 0.0882
#
# Epoch 00099: loss did not improve from 0.08775
# Epoch 100/100
# 1800/1800 [==============================] - 81s 45ms/step - loss: 0.0897
#
# Epoch 00100: loss did not improve from 0.08775

# %%
# If the execution is interrupted, change this
interrupted = False
if interrupted:
    new_model = load_model(model_file)
    predicted_y = new_model.predict(x_test)
else:
    predicted_y = autoencoder.predict(x_test)

# %%
pretty_print(x_test)

# %%
pretty_print(predicted_y)

# %%
pretty_print(y_test)

# %%
psnr = []
ssim = []
wang = [] # Z. Wang et al., 2004
for i in range(len(x_test)):
    psnr.append(skimage.measure.compare_psnr(y_test[i], x_test[i]))
    ssim.append(skimage.measure.compare_ssim(y_test[i].reshape(128, 128), x_test[i].reshape(128, 128)))
    wang.append(skimage.measure.compare_ssim(
        y_test[i].reshape(128, 128), 
        x_test[i].reshape(128, 128),
        gaussian_weights=True,
        sigma=1.5,
        use_sample_covariance=False
    ))
print("PSNR is {:.2f}".format(np.mean(psnr)))
print("Generic SSIM is {:.2%}".format(np.mean(ssim)))
print("Wang SSIM is {:.2%}".format(np.mean(wang)))
# Out:
# PSNR is 6.57
# Generic SSIM is 7.81%
# Wang SSIM is 8.45%

# %%
psnr = []
ssim = []
wang = [] # Z. Wang et al., 2004
for i in range(len(x_test)):
    psnr.append(skimage.measure.compare_psnr(y_test[i], predicted_y[i]))
    ssim.append(skimage.measure.compare_ssim(y_test[i].reshape(128, 128), predicted_y[i].reshape(128, 128)))
    wang.append(skimage.measure.compare_ssim(
        y_test[i].reshape(128, 128), 
        predicted_y[i].reshape(128, 128),
        gaussian_weights=True,
        sigma=1.5,
        use_sample_covariance=False
    ))
print("PSNR is {:.2f}".format(np.mean(psnr)))
print("Generic SSIM is {:.2%}".format(np.mean(ssim)))
print("Wang SSIM is {:.2%}".format(np.mean(wang)))
# Out:
# PSNR is 17.98
# Generic SSIM is 81.11%
# Wang SSIM is 80.27%

# %%
def pretty_print_t(data, title, n=10):
    plt.figure(figsize=(2 * n, 2))
    for i in range(1, n+1):
        ax = plt.subplot(1, n, i)
        plt.imshow(data[i][0].reshape(image_dims))
        plt.gray()
        ax.set_title(title.format(data[i][1]))
        ax.get_xaxis().set_visible(False)
        ax.get_yaxis().set_visible(False)
    plt.show()

# %%
psnr = []
ssim = []
wang = [] # Z. Wang et al., 2004
for i in range(len(x_test)):
    psnr.append(skimage.measure.compare_psnr(y_test[i], predicted_y[i]))
    ssim.append(skimage.measure.compare_ssim(y_test[i].reshape(128, 128), predicted_y[i].reshape(128, 128)))
    wang.append((y_test[i].reshape(128, 128), skimage.measure.compare_ssim(
        y_test[i].reshape(128, 128), 
        predicted_y[i].reshape(128, 128),
        gaussian_weights=True,
        sigma=1.5,
        use_sample_covariance=False
    )))
print("PSNR is {:.2f}".format(np.mean(psnr)))
print("Generic SSIM is {:.2%}".format(np.mean(ssim)))
# print("Wang PSNR is {:.2%}".format(np.mean(wang)))
pretty_print_t(wang, "W SSIM: {:.1%}")
# Out:
# PSNR is 17.98
# Generic SSIM is 81.11%
