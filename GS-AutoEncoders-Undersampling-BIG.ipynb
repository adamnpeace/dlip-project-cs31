# %% [markdown]
# # Image Denoiser using 2-layer

# %%
import os
import skimage
import numpy as np
import pandas as pd
import tensorflow as tf
from sklearn.model_selection import train_test_split
from matplotlib import pyplot as plt

from keras.layers import Input, Dense, Conv2D, MaxPooling2D, UpSampling2D
from keras.models import Model, load_model
from keras.callbacks import ModelCheckpoint
from keras import backend as K
# Out:
# Using TensorFlow backend.

# %%
model_file = "greyscale_ae_BIG_model.h5"
folder_path = "data/greyscale_undersampled_pairs"
num_samples = 10000
image_dims = (128, 128)

# %%
def pretty_print(data, n=10):
    plt.figure(figsize=(2 * n, 2))
    for i in range(1, n+1):
        ax = plt.subplot(1, n, i)
        plt.imshow(data[i].reshape(image_dims))
        plt.gray()
        ax.get_xaxis().set_visible(False)
        ax.get_yaxis().set_visible(False)
    plt.show()

# %%
x = np.ndarray((num_samples, image_dims[0], image_dims[1]))
y = np.ndarray((num_samples, image_dims[0], image_dims[1]))
for i in range(num_samples):
    x[i] = skimage.io.imread("{}/f_fbp/{}.tif".format(folder_path, i))
    y[i] = skimage.io.imread("{}/f_true/{}.tif".format(folder_path, i))
    
# Normalize values
x = x.astype('float32') / 255.
y = y.astype('float32') / 255.

# Desired shape for keras is (n_samples, x, y, n_channels)
x = np.reshape(x, (len(x), image_dims[0], image_dims[1], 1))
y = np.reshape(y, (len(y), image_dims[0], image_dims[1], 1))

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.1, random_state=42)

# %%
y_train.shape
# Out:
# (9000, 128, 128, 1)

# %%
y_test.shape
# Out:
# (1000, 128, 128, 1)

# %%
pretty_print(x_test)

# %%
pretty_print(y_test)

# %%
input_img = Input(shape=(128, 128, 1)) # x, y, n_channels

# Model Architecture
x = Conv2D(32, (3, 3), activation='relu', padding='same')(input_img)
x = MaxPooling2D((2, 2), padding='same')(x)
x = Conv2D(32, (3, 3), activation='relu', padding='same')(x)
encoded = MaxPooling2D((2, 2), padding='same')(x)

# at this point the representation is (7, 7, 32)

x = Conv2D(32, (3, 3), activation='relu', padding='same')(encoded)
x = UpSampling2D((2, 2))(x)
x = Conv2D(32, (3, 3), activation='relu', padding='same')(x)
x = UpSampling2D((2, 2))(x)
decoded = Conv2D(1, (3, 3), activation='sigmoid', padding='same')(x)

autoencoder = Model(input_img, decoded)
autoencoder.compile(optimizer='adadelta', loss='binary_crossentropy')
# Out:
# WARNING:tensorflow:From /Users/ap/.pyenv/versions/anaconda3-5.2.0/lib/python3.6/site-packages/tensorflow/python/ops/resource_variable_ops.py:435: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.

# %%
# Define the model checkpoint
filepath = model_file
checkpoint = ModelCheckpoint(filepath, monitor='loss', verbose=1, save_best_only=True, mode='min')
callbacks_list = [checkpoint]

# %%
autoencoder.fit(x_train, y_train,
                epochs=100,
                batch_size=128,
                shuffle=True,
                callbacks=callbacks_list
               )
# Out:
# WARNING:tensorflow:From /Users/ap/.pyenv/versions/anaconda3-5.2.0/lib/python3.6/site-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Epoch 1/100
# 9000/9000 [==============================] - 393s 44ms/step - loss: 0.4153
#
# Epoch 00001: loss improved from inf to 0.41531, saving model to greyscale_ae_BIG_model.h5
# Epoch 2/100
# 9000/9000 [==============================] - 391s 43ms/step - loss: 0.2403
#
# Epoch 00002: loss improved from 0.41531 to 0.24032, saving model to greyscale_ae_BIG_model.h5
# Epoch 3/100
# 9000/9000 [==============================] - 391s 43ms/step - loss: 0.2127
#
# Epoch 00003: loss improved from 0.24032 to 0.21273, saving model to greyscale_ae_BIG_model.h5
# Epoch 4/100
# 9000/9000 [==============================] - 391s 43ms/step - loss: 0.2041
#
# Epoch 00004: loss improved from 0.21273 to 0.20409, saving model to greyscale_ae_BIG_model.h5
# Epoch 5/100
# 9000/9000 [==============================] - 392s 44ms/step - loss: 0.1967
#
# Epoch 00005: loss improved from 0.20409 to 0.19669, saving model to greyscale_ae_BIG_model.h5
# Epoch 6/100
# 9000/9000 [==============================] - 392s 44ms/step - loss: 0.1874
#
# Epoch 00006: loss improved from 0.19669 to 0.18741, saving model to greyscale_ae_BIG_model.h5
# Epoch 7/100
# 9000/9000 [==============================] - 391s 43ms/step - loss: 0.1813
#
# Epoch 00007: loss improved from 0.18741 to 0.18126, saving model to greyscale_ae_BIG_model.h5
# Epoch 8/100
# 9000/9000 [==============================] - 392s 44ms/step - loss: 0.1773
#
# Epoch 00008: loss improved from 0.18126 to 0.17725, saving model to greyscale_ae_BIG_model.h5
# Epoch 9/100
# 9000/9000 [==============================] - 392s 44ms/step - loss: 0.1753
#
# Epoch 00009: loss improved from 0.17725 to 0.17528, saving model to greyscale_ae_BIG_model.h5
# Epoch 10/100
# 9000/9000 [==============================] - 392s 44ms/step - loss: 0.1704
#
# Epoch 00010: loss improved from 0.17528 to 0.17042, saving model to greyscale_ae_BIG_model.h5
# Epoch 11/100
# 9000/9000 [==============================] - 392s 44ms/step - loss: 0.1711
#
# Epoch 00011: loss did not improve from 0.17042
# Epoch 12/100
# 9000/9000 [==============================] - 392s 44ms/step - loss: 0.1669
#
# Epoch 00012: loss improved from 0.17042 to 0.16694, saving model to greyscale_ae_BIG_model.h5
# Epoch 13/100
# 9000/9000 [==============================] - 392s 44ms/step - loss: 0.1664
#
# Epoch 00013: loss improved from 0.16694 to 0.16643, saving model to greyscale_ae_BIG_model.h5
# Epoch 14/100
# 9000/9000 [==============================] - 394s 44ms/step - loss: 0.1646
#
# Epoch 00014: loss improved from 0.16643 to 0.16464, saving model to greyscale_ae_BIG_model.h5
# Epoch 15/100
# 9000/9000 [==============================] - 392s 44ms/step - loss: 0.1640
#
# Epoch 00015: loss improved from 0.16464 to 0.16396, saving model to greyscale_ae_BIG_model.h5
# Epoch 16/100
# 9000/9000 [==============================] - 392s 44ms/step - loss: 0.1624
#
# Epoch 00016: loss improved from 0.16396 to 0.16240, saving model to greyscale_ae_BIG_model.h5
# Epoch 17/100
# 9000/9000 [==============================] - 393s 44ms/step - loss: 0.1627
#
# Epoch 00017: loss did not improve from 0.16240
# Epoch 18/100
# 9000/9000 [==============================] - 392s 44ms/step - loss: 0.1609
#
# Epoch 00018: loss improved from 0.16240 to 0.16092, saving model to greyscale_ae_BIG_model.h5
# Epoch 19/100
# 9000/9000 [==============================] - 393s 44ms/step - loss: 0.1600
#
# Epoch 00019: loss improved from 0.16092 to 0.15999, saving model to greyscale_ae_BIG_model.h5
# Epoch 20/100
# 9000/9000 [==============================] - 392s 44ms/step - loss: 0.1598
#
# Epoch 00020: loss improved from 0.15999 to 0.15984, saving model to greyscale_ae_BIG_model.h5
# Epoch 21/100
# 9000/9000 [==============================] - 392s 44ms/step - loss: 0.1591
#
# Epoch 00021: loss improved from 0.15984 to 0.15909, saving model to greyscale_ae_BIG_model.h5
# Epoch 22/100
# 9000/9000 [==============================] - 392s 44ms/step - loss: 0.1585
#
# Epoch 00022: loss improved from 0.15909 to 0.15849, saving model to greyscale_ae_BIG_model.h5
# Epoch 23/100
# 9000/9000 [==============================] - 392s 44ms/step - loss: 0.1576
#
# Epoch 00023: loss improved from 0.15849 to 0.15758, saving model to greyscale_ae_BIG_model.h5
# Epoch 24/100
# 9000/9000 [==============================] - 392s 44ms/step - loss: 0.1575
#
# Epoch 00024: loss improved from 0.15758 to 0.15752, saving model to greyscale_ae_BIG_model.h5
# Epoch 25/100
# 9000/9000 [==============================] - 392s 44ms/step - loss: 0.1561
#
# Epoch 00025: loss improved from 0.15752 to 0.15613, saving model to greyscale_ae_BIG_model.h5
# Epoch 26/100
# 9000/9000 [==============================] - 393s 44ms/step - loss: 0.1561
#
# Epoch 00026: loss improved from 0.15613 to 0.15608, saving model to greyscale_ae_BIG_model.h5
# Epoch 27/100
# 9000/9000 [==============================] - 393s 44ms/step - loss: 0.1561
#
# Epoch 00027: loss did not improve from 0.15608
# Epoch 28/100
# 9000/9000 [==============================] - 393s 44ms/step - loss: 0.1551
#
# Epoch 00028: loss improved from 0.15608 to 0.15509, saving model to greyscale_ae_BIG_model.h5
# Epoch 29/100
# 9000/9000 [==============================] - 392s 44ms/step - loss: 0.1553
#
# Epoch 00029: loss did not improve from 0.15509
# Epoch 30/100
# 9000/9000 [==============================] - 392s 44ms/step - loss: 0.1545
#
# Epoch 00030: loss improved from 0.15509 to 0.15454, saving model to greyscale_ae_BIG_model.h5
# Epoch 31/100
# 9000/9000 [==============================] - 392s 44ms/step - loss: 0.1547
#
# Epoch 00031: loss did not improve from 0.15454
# Epoch 32/100
# 9000/9000 [==============================] - 393s 44ms/step - loss: 0.1547
#
# Epoch 00032: loss did not improve from 0.15454
# Epoch 33/100
# 9000/9000 [==============================] - 392s 44ms/step - loss: 0.1537
#
# Epoch 00033: loss improved from 0.15454 to 0.15370, saving model to greyscale_ae_BIG_model.h5
# Epoch 34/100
# 9000/9000 [==============================] - 393s 44ms/step - loss: 0.1534
#
# Epoch 00034: loss improved from 0.15370 to 0.15337, saving model to greyscale_ae_BIG_model.h5
# Epoch 35/100
# 9000/9000 [==============================] - 393s 44ms/step - loss: 0.1535
#
# Epoch 00035: loss did not improve from 0.15337
# Epoch 36/100
# 9000/9000 [==============================] - 393s 44ms/step - loss: 0.1524
#
# Epoch 00036: loss improved from 0.15337 to 0.15242, saving model to greyscale_ae_BIG_model.h5
# Epoch 37/100
# 9000/9000 [==============================] - 393s 44ms/step - loss: 0.1530
#
# Epoch 00037: loss did not improve from 0.15242
# Epoch 38/100
# 9000/9000 [==============================] - 393s 44ms/step - loss: 0.1519
#
# Epoch 00038: loss improved from 0.15242 to 0.15191, saving model to greyscale_ae_BIG_model.h5
# Epoch 39/100
# 9000/9000 [==============================] - 392s 44ms/step - loss: 0.1517
#
# Epoch 00039: loss improved from 0.15191 to 0.15166, saving model to greyscale_ae_BIG_model.h5
# Epoch 40/100
# 9000/9000 [==============================] - 392s 44ms/step - loss: 0.1518
#
# Epoch 00040: loss did not improve from 0.15166
# Epoch 41/100
# 9000/9000 [==============================] - 392s 44ms/step - loss: 0.1520
#
# Epoch 00041: loss did not improve from 0.15166
# Epoch 42/100
# 9000/9000 [==============================] - 393s 44ms/step - loss: 0.1514
#
# Epoch 00042: loss improved from 0.15166 to 0.15142, saving model to greyscale_ae_BIG_model.h5
# Epoch 43/100
# 9000/9000 [==============================] - 393s 44ms/step - loss: 0.1511
#
# Epoch 00043: loss improved from 0.15142 to 0.15105, saving model to greyscale_ae_BIG_model.h5
# Epoch 44/100
# 9000/9000 [==============================] - 392s 44ms/step - loss: 0.1505
#
# Epoch 00044: loss improved from 0.15105 to 0.15048, saving model to greyscale_ae_BIG_model.h5
# Epoch 45/100
# 9000/9000 [==============================] - 393s 44ms/step - loss: 0.1510
#
# Epoch 00045: loss did not improve from 0.15048
# Epoch 46/100
# 9000/9000 [==============================] - 392s 44ms/step - loss: 0.1505
#
# Epoch 00046: loss did not improve from 0.15048
# Epoch 47/100
# 9000/9000 [==============================] - 392s 44ms/step - loss: 0.1502
#
# Epoch 00047: loss improved from 0.15048 to 0.15020, saving model to greyscale_ae_BIG_model.h5
# Epoch 48/100
# 9000/9000 [==============================] - 392s 44ms/step - loss: 0.1500
#
# Epoch 00048: loss improved from 0.15020 to 0.14999, saving model to greyscale_ae_BIG_model.h5
# Epoch 49/100
# 9000/9000 [==============================] - 392s 44ms/step - loss: 0.1499
#
# Epoch 00049: loss improved from 0.14999 to 0.14993, saving model to greyscale_ae_BIG_model.h5
# Epoch 50/100
# 9000/9000 [==============================] - 393s 44ms/step - loss: 0.1499
#
# Epoch 00050: loss improved from 0.14993 to 0.14988, saving model to greyscale_ae_BIG_model.h5
# Epoch 51/100
# 9000/9000 [==============================] - 393s 44ms/step - loss: 0.1492
#
# Epoch 00051: loss improved from 0.14988 to 0.14918, saving model to greyscale_ae_BIG_model.h5
# Epoch 52/100
# 9000/9000 [==============================] - 393s 44ms/step - loss: 0.1496
#
# Epoch 00052: loss did not improve from 0.14918
# Epoch 53/100
# 9000/9000 [==============================] - 393s 44ms/step - loss: 0.1491
#
# Epoch 00053: loss improved from 0.14918 to 0.14910, saving model to greyscale_ae_BIG_model.h5
# Epoch 54/100
# 9000/9000 [==============================] - 393s 44ms/step - loss: 0.1489
#
# Epoch 00054: loss improved from 0.14910 to 0.14891, saving model to greyscale_ae_BIG_model.h5
# Epoch 55/100
# 9000/9000 [==============================] - 393s 44ms/step - loss: 0.1494
#
# Epoch 00055: loss did not improve from 0.14891
# Epoch 56/100
# 9000/9000 [==============================] - 393s 44ms/step - loss: 0.1485
#
# Epoch 00056: loss improved from 0.14891 to 0.14850, saving model to greyscale_ae_BIG_model.h5
# Epoch 57/100
# 9000/9000 [==============================] - 392s 44ms/step - loss: 0.1479
#
# Epoch 00057: loss improved from 0.14850 to 0.14793, saving model to greyscale_ae_BIG_model.h5
# Epoch 58/100
# 9000/9000 [==============================] - 393s 44ms/step - loss: 0.1483
#
# Epoch 00058: loss did not improve from 0.14793
# Epoch 59/100
# 9000/9000 [==============================] - 393s 44ms/step - loss: 0.1484
#
# Epoch 00059: loss did not improve from 0.14793
# Epoch 60/100
# 9000/9000 [==============================] - 393s 44ms/step - loss: 0.1479
#
# Epoch 00060: loss improved from 0.14793 to 0.14786, saving model to greyscale_ae_BIG_model.h5
# Epoch 61/100
# 9000/9000 [==============================] - 393s 44ms/step - loss: 0.1480
#
# Epoch 00061: loss did not improve from 0.14786
# Epoch 62/100
# 9000/9000 [==============================] - 393s 44ms/step - loss: 0.1483
#
# Epoch 00062: loss did not improve from 0.14786
# Epoch 63/100
# 9000/9000 [==============================] - 393s 44ms/step - loss: 0.1477
#
# Epoch 00063: loss improved from 0.14786 to 0.14770, saving model to greyscale_ae_BIG_model.h5
# Epoch 64/100
# 9000/9000 [==============================] - 393s 44ms/step - loss: 0.1483
#
# Epoch 00064: loss did not improve from 0.14770
# Epoch 65/100
# 9000/9000 [==============================] - 393s 44ms/step - loss: 0.1480
#
# Epoch 00065: loss did not improve from 0.14770
# Epoch 66/100
# 9000/9000 [==============================] - 393s 44ms/step - loss: 0.1473
#
# Epoch 00066: loss improved from 0.14770 to 0.14733, saving model to greyscale_ae_BIG_model.h5
# Epoch 67/100
# 9000/9000 [==============================] - 393s 44ms/step - loss: 0.1477
#
# Epoch 00067: loss did not improve from 0.14733
# Epoch 68/100
# 9000/9000 [==============================] - 393s 44ms/step - loss: 0.1471
#
# Epoch 00068: loss improved from 0.14733 to 0.14709, saving model to greyscale_ae_BIG_model.h5
# Epoch 69/100
# 9000/9000 [==============================] - 393s 44ms/step - loss: 0.1473
#
# Epoch 00069: loss did not improve from 0.14709
# Epoch 70/100
# 9000/9000 [==============================] - 393s 44ms/step - loss: 0.1468
#
# Epoch 00070: loss improved from 0.14709 to 0.14675, saving model to greyscale_ae_BIG_model.h5
# Epoch 71/100
# 9000/9000 [==============================] - 393s 44ms/step - loss: 0.1464
#
# Epoch 00071: loss improved from 0.14675 to 0.14644, saving model to greyscale_ae_BIG_model.h5
# Epoch 72/100
# 9000/9000 [==============================] - 393s 44ms/step - loss: 0.1469
#
# Epoch 00072: loss did not improve from 0.14644
# Epoch 73/100
# 9000/9000 [==============================] - 393s 44ms/step - loss: 0.1472
#
# Epoch 00073: loss did not improve from 0.14644
# Epoch 74/100
# 9000/9000 [==============================] - 393s 44ms/step - loss: 0.1463
#
# Epoch 00074: loss improved from 0.14644 to 0.14635, saving model to greyscale_ae_BIG_model.h5
# Epoch 75/100
# 9000/9000 [==============================] - 393s 44ms/step - loss: 0.1466
#
# Epoch 00075: loss did not improve from 0.14635
# Epoch 76/100
# 9000/9000 [==============================] - 393s 44ms/step - loss: 0.1470
#
# Epoch 00076: loss did not improve from 0.14635
# Epoch 77/100
# 9000/9000 [==============================] - 393s 44ms/step - loss: 0.1463
#
# Epoch 00077: loss improved from 0.14635 to 0.14631, saving model to greyscale_ae_BIG_model.h5
# Epoch 78/100
# 9000/9000 [==============================] - 393s 44ms/step - loss: 0.1464
#
# Epoch 00078: loss did not improve from 0.14631
# Epoch 79/100
# 9000/9000 [==============================] - 393s 44ms/step - loss: 0.1469
#
# Epoch 00079: loss did not improve from 0.14631
# Epoch 80/100
# 9000/9000 [==============================] - 393s 44ms/step - loss: 0.1460
#
# Epoch 00080: loss improved from 0.14631 to 0.14597, saving model to greyscale_ae_BIG_model.h5
# Epoch 81/100
# 9000/9000 [==============================] - 393s 44ms/step - loss: 0.1468
#
# Epoch 00081: loss did not improve from 0.14597
# Epoch 82/100
# 9000/9000 [==============================] - 394s 44ms/step - loss: 0.1463
#
# Epoch 00082: loss did not improve from 0.14597
# Epoch 83/100
# 9000/9000 [==============================] - 393s 44ms/step - loss: 0.1458
#
# Epoch 00083: loss improved from 0.14597 to 0.14583, saving model to greyscale_ae_BIG_model.h5
# Epoch 84/100
# 9000/9000 [==============================] - 393s 44ms/step - loss: 0.1461
#
# Epoch 00084: loss did not improve from 0.14583
# Epoch 85/100
# 9000/9000 [==============================] - 393s 44ms/step - loss: 0.1463
#
# Epoch 00085: loss did not improve from 0.14583
# Epoch 86/100
# 9000/9000 [==============================] - 392s 44ms/step - loss: 0.1455
#
# Epoch 00086: loss improved from 0.14583 to 0.14553, saving model to greyscale_ae_BIG_model.h5
# Epoch 87/100
# 9000/9000 [==============================] - 393s 44ms/step - loss: 0.1459
#
# Epoch 00087: loss did not improve from 0.14553
# Epoch 88/100
# 9000/9000 [==============================] - 393s 44ms/step - loss: 0.1461
#
# Epoch 00088: loss did not improve from 0.14553
# Epoch 89/100
# 9000/9000 [==============================] - 393s 44ms/step - loss: 0.1457
#
# Epoch 00089: loss did not improve from 0.14553
# Epoch 90/100
# 9000/9000 [==============================] - 393s 44ms/step - loss: 0.1456
#
# Epoch 00090: loss did not improve from 0.14553
# Epoch 91/100
# 9000/9000 [==============================] - 393s 44ms/step - loss: 0.1455
#
# Epoch 00091: loss improved from 0.14553 to 0.14550, saving model to greyscale_ae_BIG_model.h5
# Epoch 92/100
# 9000/9000 [==============================] - 393s 44ms/step - loss: 0.1456
#
# Epoch 00092: loss did not improve from 0.14550
# Epoch 93/100
# 9000/9000 [==============================] - 393s 44ms/step - loss: 0.1453
#
# Epoch 00093: loss improved from 0.14550 to 0.14529, saving model to greyscale_ae_BIG_model.h5
# Epoch 94/100
# 9000/9000 [==============================] - 393s 44ms/step - loss: 0.1459
#
# Epoch 00094: loss did not improve from 0.14529
# Epoch 95/100
# 9000/9000 [==============================] - 393s 44ms/step - loss: 0.1454
#
# Epoch 00095: loss did not improve from 0.14529
# Epoch 96/100
# 9000/9000 [==============================] - 393s 44ms/step - loss: 0.1457
#
# Epoch 00096: loss did not improve from 0.14529
# Epoch 97/100
# 9000/9000 [==============================] - 396s 44ms/step - loss: 0.1450
#
# Epoch 00097: loss improved from 0.14529 to 0.14503, saving model to greyscale_ae_BIG_model.h5
# Epoch 98/100
# 9000/9000 [==============================] - 392s 44ms/step - loss: 0.1456
#
# Epoch 00098: loss did not improve from 0.14503
# Epoch 99/100
# 9000/9000 [==============================] - 393s 44ms/step - loss: 0.1452
#
# Epoch 00099: loss did not improve from 0.14503
# Epoch 100/100
# 9000/9000 [==============================] - 393s 44ms/step - loss: 0.1452
#
# Epoch 00100: loss did not improve from 0.14503

# %%
# If the execution is interrupted, change this
interrupted = False
if interrupted:
    new_model = load_model(model_file)
    predicted_y = new_model.predict(x_test)
else:
    predicted_y = autoencoder.predict(x_test)

# %%
pretty_print(x_test)

# %%
pretty_print(predicted_y)

# %%
pretty_print(y_test)

# %%
psnr = []
ssim = []
wang = [] # Z. Wang et al., 2004
for i in range(len(x_test)):
    psnr.append(skimage.measure.compare_psnr(y_test[i], x_test[i]))
    ssim.append(skimage.measure.compare_ssim(y_test[i].reshape(128, 128), x_test[i].reshape(128, 128)))
    wang.append(skimage.measure.compare_ssim(
        y_test[i].reshape(128, 128), 
        x_test[i].reshape(128, 128),
        gaussian_weights=True,
        sigma=1.5,
        use_sample_covariance=False
    ))
print("PSNR is {:.2f}".format(np.mean(psnr)))
print("Generic SSIM is {:.2%}".format(np.mean(ssim)))
print("Wang SSIM is {:.2%}".format(np.mean(wang)))
# Out:
# PSNR is 9.79
# Generic SSIM is 18.73%
# Wang SSIM is 19.60%

# %%
psnr = []
ssim = []
wang = [] # Z. Wang et al., 2004
for i in range(len(x_test)):
    psnr.append(skimage.measure.compare_psnr(y_test[i], predicted_y[i]))
    ssim.append(skimage.measure.compare_ssim(y_test[i].reshape(128, 128), predicted_y[i].reshape(128, 128)))
    wang.append(skimage.measure.compare_ssim(
        y_test[i].reshape(128, 128), 
        predicted_y[i].reshape(128, 128),
        gaussian_weights=True,
        sigma=1.5,
        use_sample_covariance=False
    ))
print("PSNR is {:.2f}".format(np.mean(psnr)))
print("Generic SSIM is {:.2%}".format(np.mean(ssim)))
print("Wang SSIM is {:.2%}".format(np.mean(wang)))
# Out:
# PSNR is 25.27
# Generic SSIM is 94.89%
# Wang SSIM is 95.08%

# %%
def pretty_print_t(data, title, n=10):
    plt.figure(figsize=(2 * n, 2))
    for i in range(1, n+1):
        ax = plt.subplot(1, n, i)
        plt.imshow(data[i][0].reshape(image_dims))
        plt.gray()
        ax.set_title(title.format(data[i][1]))
        ax.get_xaxis().set_visible(False)
        ax.get_yaxis().set_visible(False)
    plt.show()

# %%
psnr = []
ssim = []
wang = [] # Z. Wang et al., 2004
wang_img = []
for i in range(len(x_test)):
    psnr.append(skimage.measure.compare_psnr(y_test[i], predicted_y[i]))
    ssim.append(skimage.measure.compare_ssim(y_test[i].reshape(128, 128), predicted_y[i].reshape(128, 128)))
    wang.append(skimage.measure.compare_ssim(
        y_test[i].reshape(128, 128), 
        predicted_y[i].reshape(128, 128),
        gaussian_weights=True,
        sigma=1.5,
        use_sample_covariance=False
    ))
    wang_img.append((predicted_y[i].reshape(128, 128), skimage.measure.compare_ssim(
        y_test[i].reshape(128, 128), 
        predicted_y[i].reshape(128, 128),
        gaussian_weights=True,
        sigma=1.5,
        use_sample_covariance=False
    )))
print("PSNR is {:.2f}".format(np.mean(psnr)))
print("Generic SSIM is {:.2%}".format(np.mean(ssim)))
print("Wang SSIM is {:.2%}".format(np.mean(wang)))
pretty_print_t(wang_img, "W SSIM: {:.1%}")
# Out:
# PSNR is 25.27
# Generic SSIM is 94.89%
# Wang SSIM is 95.08%
